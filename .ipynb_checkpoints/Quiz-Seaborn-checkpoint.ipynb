# %% [markdown]
# 1.สร้าง DataFrame ที่เก็บยอดขายของบริษัท A,B,C,D ของปี 2014,2015,2016,2017 โดยชื่อบริษัทเป็น index และปีเป็น column. สร้างคำสั่ง numpy สุ่มเลขแบบ float ให้เป็นรายได้ของบริษัทที่อยู่ในช่วง 50 – 500 (หน่วยล้านบาท)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
Name = ['A', 'B', 'C', 'D']
Year = ['2014', '2015', '2016', '2017']
Income = np.random.uniform(50, 500, (4,4))
df = pd.DataFrame(Income, Name, Year)
df
# Out:
#          2014        2015        2016        2017
# A  305.768747  161.324883  414.344923  424.835550
# B  297.889746  327.302369   66.895007  319.468284
# C  226.994451  211.446315  274.755785  276.970366
# D  372.493543  160.377383  267.499870  305.626626

# %% [markdown]
# 2.ใช้ข้อมูลจาก DataFrame ด้านบนสร้าง Bar plot ให้แกน x เป็น ชื่อบริษัท ยอดขายเฉลี่ยเป็นแกน Y โดยสร้างกราฟแบบแนวตั้งและแนวนอน

# %%
sns.barplot(x = Name, y = df.mean(axis = 1))

# %%
sns.barplot(y = Name, x = df.mean(axis = 1))

# %% [markdown]
# 3.ใช้ข้อมูลจาก DataFrame ด้านบนสร้าง Scatter plot ให้แกน x เป็น ชื่อบริษัท ยอดขายปี 2017 เป็นแกน Y โดยสร้างกราฟแบบแนวตั้งและแนวนอน

# %%
sns.scatterplot(x=df.index, y = df['2017'], data = df)

# %% [markdown]
# ให้ import ไฟล์ titanic ไฟล์เดิมจากบทเรียน Pandas เข้าสู่ Jupyter Notebook สามารถใช้ Pandas มาร่วมทำด้วย
# 4. สร้าง count plot นับข้อมูล Embarked โดยสร้างกราฟแบบแนวตั้งและแนวนอน

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/TawanTan/Titanic/master/train.csv', na_values={})

fig = plt.figure(figsize=(5,5))
sns.countplot(x='Embarked', data = df1)

# %%
fig = plt.figure(figsize=(5,5))
sns.countplot(y='Embarked', data = df1)

# %% [markdown]
# 5. สร้าง count plot นับข้อมูล Pclass โดยสร้างกราฟแบบแนวตั้งและแนวนอน

# %%
fig = plt.figure(figsize=(5,5))
sns.countplot(x='Pclass', data = df1)

# %%
fig = plt.figure(figsize=(5,5))
sns.countplot(y='Pclass', data = df1)

# %% [markdown]
# 6. สร้าง box plot ให้แกน X เป็นเพศ และแกน Y เป็นราคา

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
fig = plt.figure(figsize=(5,5))
sns.boxplot(x='Sex', y='Fare', data=df1)

# %% [markdown]
# 7. สร้าง box plot ให้แกน X เป็นPclass และแกน Y เป็นราคา

# %%
fig = plt.figure(figsize=(5,5))
sns.boxplot(x='Pclass', y='Fare', data=df1)

# %% [markdown]
# 8. สร้าง barplot โดยให้ แกน X เป็นจุดหมายปลายทางและแกน Y เป็นราคา

# %%
fig = plt.figure(figsize=(5,5))
sns.barplot(x='Embarked', y='Fare', data=df1)

# %% [markdown]
# 9. สร้าง barplot โดยให้ แกน X เป็นPclass และแกน Y เป็นอายุ

# %%
fig = plt.figure(figsize=(5,5))
sns.barplot(x='Pclass', y='Age', data=df1)

# %% [markdown]
# 10. สร้าง Stripplot โดยให้แกน X เป็น Pclass และ แกน Y เป็นราคา

# %%
fig = plt.figure(figsize=(7,7))
sns.stripplot(x='Pclass', y='Fare', data=df1)

# %% [markdown]
# 11. สร้าง Stripplot โดยให้ แกน X เป็น Survived แกน Y เป็นอายุ และ hue เป็นเพศ

# %%
fig = plt.figure(figsize=(7,7))
sns.stripplot(x='Survived', y='Age', hue='Sex', data=df1)

# %% [markdown]
# 12. สร้าง Swarmplot โดยให้ แกน X เป็นเพศและแกน Y เป็นอายุ

# %%
fig = plt.figure(figsize=(7,7))
sns.swarmplot(x='Sex', y='Age', data=df1)
# Out:
# C:\Users\msi\anaconda3\lib\site-packages\seaborn\categorical.py:1326: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# C:\Users\msi\anaconda3\lib\site-packages\seaborn\categorical.py:1330: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %% [markdown]
# 13. สร้าง HeatMap โดย crosstab กำหนดให้ index เป็น Pclass และ column เป็นเพศ

# %%
new_df1 = pd.crosstab(df1['Pclass'], df1['Sex'])
print(new_df1)
sns.heatmap(new_df1)
# Out:
# Sex     female  male
# Pclass
# 1           94   122
# 2           76   108
# 3          144   347

# %% [markdown]
# 14. สร้าง HeatMap โดย pivot table กำหนดให้ index เป็น Pclass และ column เป็นเพศ และ values เป็น ราคา

# %%
new2_df1 = df1.pivot_table(index='Pclass', columns='Sex', values='Fare')
print(new2_df1)
sns.heatmap(new2_df1, annot=True, cmap='coolwarm')
# Out:
# Sex         female       male
# Pclass
# 1       106.125798  67.226127
# 2        21.970121  19.741782
# 3        16.118810  12.661633

# %% [markdown]
# 15. สร้าง HeatMap โดย pivot table กำหนดให้ index เป็น Pclass และ column เป็นเพศ และ values เป็น ราคา และกำหนดเส้นสีขาวขนาด 2 เป็นเส้นแบ่ง

# %%
new3_df1 = df1.pivot_table(index='Pclass', columns='Sex', values='Fare')
print(new2_df1)
sns.heatmap(new2_df1, annot=True, cmap='coolwarm', linecolor='white', linewidth=2)
# Out:
# Sex         female       male
# Pclass
# 1       106.125798  67.226127
# 2        21.970121  19.741782
# 3        16.118810  12.661633

# %% [markdown]
# 16. สร้าง Heatmap โดย Correlation ของทั้ง DataFrame

# %%
fig =plt.figure(figsize=(10,8))
sns.heatmap(df1.corr(), annot=True, cmap='coolwarm', linecolor='white', linewidth=2)

# %% [markdown]
# 17. สร้าง Clustermap ของทั้ง DataFrame

# %%
sns.clustermap(df1.corr(), annot=True)

# %% [markdown]
# 18. พิจารณาจากข้อมูลที่มีความสัมพันธ์มากที่สุดมาสร้าง Scatterplot

# %%
fig = plt.figure(figsize=(10,8))
sns.scatterplot(x='Pclass', y='Fare', data=df1)

# %% [markdown]
# 19. พิจารณาจากข้อมูลที่มีความสัมพันธ์น้อยที่สุดมาสร้าง Scatterplot และให้ hue เป็นเพศ

# %%
fig = plt.figure(figsize=(10,8))
sns.scatterplot(x='PassengerId', y='Parch', data=df1)

# %% [markdown]
# 20. สร้าง Distribution Plot ของราคาและอายุ

# %%
sns.distplot(df1['Fare'])

# %%
sns.distplot(df1['Age'])

# %% [markdown]
# 21. สร้าง Pair Plot ของทั้ง DataFrame (หรือ column ที่น่าสนใจ)

# %%
sns.pairplot(df1)
